# %% [markdown]
# # MF의 최적 파라미터 찾기

# %%
import os
import pandas as pd
import numpy as np 

base_src = '../data/drive-download-20240102T142504Z-001'
u_data_src = os.path.join(base_src, 'u.data')
r_cols = ['user_id', 'movie_id', 'rating', 'timestamp']
ratings = pd.read_csv(
    u_data_src,
    sep='\t',
    names=r_cols,
    encoding='latin-1'
)
ratings = ratings[['user_id', 'movie_id', 'rating']].astype(int)
# train test split
from sklearn.utils import shuffle
TRAIN_SIZE = 0.75
ratings = shuffle(ratings, random_state=2021)
cutoff = int(TRAIN_SIZE * len(ratings))
ratings_train = ratings.iloc[:cutoff]
ratings_test = ratings.iloc[cutoff:]

# %%
class NEW_MF():
    def __init__(self, ratings, hyper_params):
        self.R = np.array(ratings)
        # 사용자 수 (num_users)와 아이템 수 (num_items)를 받아온다
        self.num_users, self.num_items = np.shape(self.R)
        # 아래는 MF weight 조절을 위한 하이퍼파라미터
        self.K = hyper_params['K'] # 잠재요인의 수 (latent factor)
        self.alpha = hyper_params['alpha'] # 학습률
        self.beta = hyper_params['beta'] # 정규화 계수
        self.iterations = hyper_params['iterations'] # SGD 반복 횟수
        self.verbose = hyper_params['verbose'] 
        
        item_id_index = []
        index_item_id = []
        for i, one_id in enumerate(ratings):
            item_id_index.append([one_id, i])
            index_item_id.append([i, one_id])
        self.item_id_index = dict(item_id_index)
        self.index_item_id = dict(index_item_id)
        
        user_id_index = []
        index_user_id = []
        for i, one_id in enumerate(ratings.T):
            user_id_index.append([one_id, i])
            index_user_id.append([i, one_id]) 
        self.user_id_index = dict(user_id_index)
        self.index_user_id = dict(index_user_id)
        
    def rmse(self):
        # self.R에서 평점이; 있는(0이 아닌) 요소의 인덱스를 가져옴
        xs, ys = self.R.nonzero()
        # prediction과 error를 담을 리스트 변수 초기화
        self.predictions = []
        self.errors = []
        # 평점이 있는 요소 (사용자 x, 아이템 y) 각각에 대해서 아래의 코드를 실행한다.
        for x, y in zip(xs, ys):
            # 사용자 x 아이템 y에 대해서 평점 예측치를 get_prediction()으로 구한다.
            prediction = self.get_prediction(x, y)
            # 예측치를 prediction에 담고, 실제값과의 오차를 구해서 errors에 담는다.
            self.predictions.append(prediction)
            self.errors.append(self.R[x, y] - prediction) # 실제값 - 예측값
        # errors를 numpy array로 변환한다.
        self.predictions = np.array(self.predictions)
        self.errors = np.array(self.errors)
        
        return np.sqrt(np.mean(self.errors**2))
   
    def sgd(self):
        for i, j, r in self.samples:
            # 사용자 i, 아이템 j에 대한 평점 예측치 계산
            prediction = self.get_prediction(i, j)
            e = (r - prediction) # (실제값 - 예측값) 오차 계산
            
            # 사용자 평가 경향 계산 및 업데이트
            self.b_u[i] += self.alpha * (e - (self.beta * self.b_u[i]))
            # 아이템 평가 경향 계산 및 업데이트
            self.b_d[j] += self.alpha * (e - (self.beta * self.b_d[j]))
            
            # P 행렬 계산 및 업데이트
            self.P[i, :] += self.alpha * ((e * self.Q[j, :]) - (self.beta * self.P[i, :]))
            # Q 행렬 계산 및 업데이트
            self.Q[j, :] += self.alpha * ((e * self.P[i, :]) - (self.beta * self.Q[j, :]))

    def get_prediction(self, i, j):
        # 사용자 i, 아이템 j에 대한 평점 예측치를 계산한다.
        return self.b + self.b_u[i] + self.b_d[j] + self.P[i, :].dot(self.Q[j,].T)

    # test set
    def set_test(self, ratings_test):
        test_set = []
        for i in range(len(ratings_test)):
            x = self.user_id_index[ratings_test.iloc[i, 0]]
            y = self.item_id_index[ratings_test.iloc[i, 1]]
            z = ratings_test.iloc[i, 2]
            test_set.append([x, y, z])
            # 테스트 셋에으로 추출한 데이터는 원본 행렬에서 평점을 지운다.
            self.R[x, y] = 0
        self.test_set = test_set
        return test_set
    
    # test set에 대한 RMSE 계산
    def test_rmse(self):
        error = 0
        for one_set in self.test_set:
            predicted = self.get_prediction(one_set[0], one_set[1])
            #  pow e => e^2
            error += pow(one_set[2] - predicted, 2)
        return np.sqrt(error/len(self.test_set))
    
    def test(self):
        self.P = np.random.normal(scale= 1./self.K,
                                  size=(self.num_users, self.K))
        self.Q = np.random.normal(scale= 1./self.K,
                                  size=(self.num_items, self.K))
        self.b_u = np.zeros(self.num_users)
        self.b_d = np.zeros(self.num_items) 
        self.b = np.mean(self.R[self.R.nonzero()]) # 전체 평균
        
        rows, columns = self.R.nonzero()
        self.samples = [(i, j, self.R[i,j]) for i, j in zip(rows, columns)]
        
        training_process = []
        for i in range(self.iterations):
            np.random.shuffle(self.samples)
            self.sgd()
            rmse1 = self.rmse()
            rmse2 = self.test_rmse()
            training_process.append((i+1, rmse1, rmse2))
            if self.verbose:
                if (i+1) % 10 == 0:
                    print('Iteration: %d ; Train RMSE = %.4f ; Test RMSE = %.4f' % (i+1, rmse1, rmse2))
        return training_process
    
    def get_one_prediction(self, user_id, item_id):
        return self.get_prediction(self.user_id_index[user_id],
                                   self.item_id_index[item_id])

    def full_prediction(self):
        return self.b + self.b_u[:,np.newaxis] + self.b_d[np.newaxis:,] + self.P.dot(self.Q.T)

# %%
# 최적의 K 값 찾기
results = []
index = []

R_temp = ratings.pivot(index='user_id', columns='movie_id', values='rating').fillna(0)

for K in range(50,261,10):
    print(f'K = {K}')
    hyper_params = {
        'K': K,
        'alpha': 0.001,
        'beta': 0.02,
        'iterations': 300,
        'verbose': True
    }
    mf = NEW_MF(R_temp, hyper_params)
    
    test_set = mf.set_test(ratings_test)
    result = mf.test()
    index.append(K)
    results.append(result)
# Out:
# K = 50
# Iteration: 10 ; Train RMSE = 0.9669 ; Test RMSE = 0.9807
# Iteration: 20 ; Train RMSE = 0.9417 ; Test RMSE = 0.9622
# Iteration: 30 ; Train RMSE = 0.9305 ; Test RMSE = 0.9552
# Iteration: 40 ; Train RMSE = 0.9239 ; Test RMSE = 0.9515
# Iteration: 50 ; Train RMSE = 0.9195 ; Test RMSE = 0.9494
# Iteration: 60 ; Train RMSE = 0.9161 ; Test RMSE = 0.9479
# Iteration: 70 ; Train RMSE = 0.9131 ; Test RMSE = 0.9469
# Iteration: 80 ; Train RMSE = 0.9101 ; Test RMSE = 0.9461
# Iteration: 90 ; Train RMSE = 0.9067 ; Test RMSE = 0.9452
# Iteration: 100 ; Train RMSE = 0.9024 ; Test RMSE = 0.9441
# Iteration: 110 ; Train RMSE = 0.8967 ; Test RMSE = 0.9426
# Iteration: 120 ; Train RMSE = 0.8889 ; Test RMSE = 0.9404
# Iteration: 130 ; Train RMSE = 0.8785 ; Test RMSE = 0.9375
# Iteration: 140 ; Train RMSE = 0.8655 ; Test RMSE = 0.9339
# Iteration: 150 ; Train RMSE = 0.8502 ; Test RMSE = 0.9303
# Iteration: 160 ; Train RMSE = 0.8332 ; Test RMSE = 0.9269
# Iteration: 170 ; Train RMSE = 0.8151 ; Test RMSE = 0.9240
# Iteration: 180 ; Train RMSE = 0.7958 ; Test RMSE = 0.9217
# Iteration: 190 ; Train RMSE = 0.7758 ; Test RMSE = 0.9201
# Iteration: 200 ; Train RMSE = 0.7550 ; Test RMSE = 0.9191
# Iteration: 210 ; Train RMSE = 0.7337 ; Test RMSE = 0.9188
# Iteration: 220 ; Train RMSE = 0.7123 ; Test RMSE = 0.9191
# Iteration: 230 ; Train RMSE = 0.6909 ; Test RMSE = 0.9200
# Iteration: 240 ; Train RMSE = 0.6697 ; Test RMSE = 0.9215
# Iteration: 250 ; Train RMSE = 0.6491 ; Test RMSE = 0.9234
# Iteration: 260 ; Train RMSE = 0.6290 ; Test RMSE = 0.9258
# Iteration: 270 ; Train RMSE = 0.6097 ; Test RMSE = 0.9285
# Iteration: 280 ; Train RMSE = 0.5912 ; Test RMSE = 0.9314
# Iteration: 290 ; Train RMSE = 0.5736 ; Test RMSE = 0.9345
# Iteration: 300 ; Train RMSE = 0.5569 ; Test RMSE = 0.9376
# K = 60
# Iteration: 10 ; Train RMSE = 0.9669 ; Test RMSE = 0.9807
# Iteration: 20 ; Train RMSE = 0.9418 ; Test RMSE = 0.9623
# Iteration: 30 ; Train RMSE = 0.9307 ; Test RMSE = 0.9552
# Iteration: 40 ; Train RMSE = 0.9242 ; Test RMSE = 0.9515
# Iteration: 50 ; Train RMSE = 0.9198 ; Test RMSE = 0.9494
# Iteration: 60 ; Train RMSE = 0.9165 ; Test RMSE = 0.9480
# Iteration: 70 ; Train RMSE = 0.9136 ; Test RMSE = 0.9469
# Iteration: 80 ; Train RMSE = 0.9108 ; Test RMSE = 0.9461
# Iteration: 90 ; Train RMSE = 0.9076 ; Test RMSE = 0.9452
# Iteration: 100 ; Train RMSE = 0.9036 ; Test RMSE = 0.9442
# Iteration: 110 ; Train RMSE = 0.8983 ; Test RMSE = 0.9427
# Iteration: 120 ; Train RMSE = 0.8909 ; Test RMSE = 0.9405
# Iteration: 130 ; Train RMSE = 0.8812 ; Test RMSE = 0.9376
# Iteration: 140 ; Train RMSE = 0.8691 ; Test RMSE = 0.9343
# Iteration: 150 ; Train RMSE = 0.8550 ; Test RMSE = 0.9309
# Iteration: 160 ; Train RMSE = 0.8393 ; Test RMSE = 0.9276
# Iteration: 170 ; Train RMSE = 0.8221 ; Test RMSE = 0.9247
# Iteration: 180 ; Train RMSE = 0.8036 ; Test RMSE = 0.9222
# Iteration: 190 ; Train RMSE = 0.7837 ; Test RMSE = 0.9203
# Iteration: 200 ; Train RMSE = 0.7626 ; Test RMSE = 0.9188
# Iteration: 210 ; Train RMSE = 0.7408 ; Test RMSE = 0.9180
# Iteration: 220 ; Train RMSE = 0.7185 ; Test RMSE = 0.9179
# Iteration: 230 ; Train RMSE = 0.6959 ; Test RMSE = 0.9185
# Iteration: 240 ; Train RMSE = 0.6735 ; Test RMSE = 0.9196
# Iteration: 250 ; Train RMSE = 0.6514 ; Test RMSE = 0.9213
# Iteration: 260 ; Train RMSE = 0.6299 ; Test RMSE = 0.9234
# Iteration: 270 ; Train RMSE = 0.6090 ; Test RMSE = 0.9259
# Iteration: 280 ; Train RMSE = 0.5889 ; Test RMSE = 0.9287
# Iteration: 290 ; Train RMSE = 0.5697 ; Test RMSE = 0.9317
# Iteration: 300 ; Train RMSE = 0.5514 ; Test RMSE = 0.9348
# K = 70
# Iteration: 10 ; Train RMSE = 0.9670 ; Test RMSE = 0.9807
# Iteration: 20 ; Train RMSE = 0.9419 ; Test RMSE = 0.9622
# Iteration: 30 ; Train RMSE = 0.9308 ; Test RMSE = 0.9552
# Iteration: 40 ; Train RMSE = 0.9244 ; Test RMSE = 0.9515
# Iteration: 50 ; Train RMSE = 0.9200 ; Test RMSE = 0.9493
# Iteration: 60 ; Train RMSE = 0.9168 ; Test RMSE = 0.9479
# Iteration: 70 ; Train RMSE = 0.9140 ; Test RMSE = 0.9468
# Iteration: 80 ; Train RMSE = 0.9113 ; Test RMSE = 0.9459
# Iteration: 90 ; Train RMSE = 0.9082 ; Test RMSE = 0.9449
# Iteration: 100 ; Train RMSE = 0.9042 ; Test RMSE = 0.9436
# Iteration: 110 ; Train RMSE = 0.8988 ; Test RMSE = 0.9418
# Iteration: 120 ; Train RMSE = 0.8915 ; Test RMSE = 0.9393
# Iteration: 130 ; Train RMSE = 0.8819 ; Test RMSE = 0.9361
# Iteration: 140 ; Train RMSE = 0.8704 ; Test RMSE = 0.9325
# Iteration: 150 ; Train RMSE = 0.8572 ; Test RMSE = 0.9291
# Iteration: 160 ; Train RMSE = 0.8427 ; Test RMSE = 0.9259
# Iteration: 170 ; Train RMSE = 0.8267 ; Test RMSE = 0.9231
# Iteration: 180 ; Train RMSE = 0.8092 ; Test RMSE = 0.9206
# Iteration: 190 ; Train RMSE = 0.7902 ; Test RMSE = 0.9185
# Iteration: 200 ; Train RMSE = 0.7698 ; Test RMSE = 0.9169
# Iteration: 210 ; Train RMSE = 0.7483 ; Test RMSE = 0.9159
# Iteration: 220 ; Train RMSE = 0.7259 ; Test RMSE = 0.9154
# Iteration: 230 ; Train RMSE = 0.7031 ; Test RMSE = 0.9156
# Iteration: 240 ; Train RMSE = 0.6800 ; Test RMSE = 0.9163
# Iteration: 250 ; Train RMSE = 0.6570 ; Test RMSE = 0.9175
# Iteration: 260 ; Train RMSE = 0.6344 ; Test RMSE = 0.9191
# Iteration: 270 ; Train RMSE = 0.6124 ; Test RMSE = 0.9211
# Iteration: 280 ; Train RMSE = 0.5910 ; Test RMSE = 0.9234
# Iteration: 290 ; Train RMSE = 0.5705 ; Test RMSE = 0.9259
# Iteration: 300 ; Train RMSE = 0.5509 ; Test RMSE = 0.9285
# K = 80
# Iteration: 10 ; Train RMSE = 0.9670 ; Test RMSE = 0.9807
# Iteration: 20 ; Train RMSE = 0.9420 ; Test RMSE = 0.9622
# Iteration: 30 ; Train RMSE = 0.9309 ; Test RMSE = 0.9552
# Iteration: 40 ; Train RMSE = 0.9246 ; Test RMSE = 0.9515
# Iteration: 50 ; Train RMSE = 0.9203 ; Test RMSE = 0.9493
# Iteration: 60 ; Train RMSE = 0.9172 ; Test RMSE = 0.9480
# Iteration: 70 ; Train RMSE = 0.9146 ; Test RMSE = 0.9470
# Iteration: 80 ; Train RMSE = 0.9122 ; Test RMSE = 0.9462
# Iteration: 90 ; Train RMSE = 0.9095 ; Test RMSE = 0.9454
# Iteration: 100 ; Train RMSE = 0.9062 ; Test RMSE = 0.9445
# Iteration: 110 ; Train RMSE = 0.9019 ; Test RMSE = 0.9432
# Iteration: 120 ; Train RMSE = 0.8959 ; Test RMSE = 0.9413
# Iteration: 130 ; Train RMSE = 0.8878 ; Test RMSE = 0.9387
# Iteration: 140 ; Train RMSE = 0.8773 ; Test RMSE = 0.9354
# Iteration: 150 ; Train RMSE = 0.8648 ; Test RMSE = 0.9318
# Iteration: 160 ; Train RMSE = 0.8506 ; Test RMSE = 0.9282
# Iteration: 170 ; Train RMSE = 0.8348 ; Test RMSE = 0.9248
# Iteration: 180 ; Train RMSE = 0.8176 ; Test RMSE = 0.9217
# Iteration: 190 ; Train RMSE = 0.7988 ; Test RMSE = 0.9190
# Iteration: 200 ; Train RMSE = 0.7788 ; Test RMSE = 0.9167
# Iteration: 210 ; Train RMSE = 0.7575 ; Test RMSE = 0.9150
# Iteration: 220 ; Train RMSE = 0.7353 ; Test RMSE = 0.9139
# Iteration: 230 ; Train RMSE = 0.7124 ; Test RMSE = 0.9134
# Iteration: 240 ; Train RMSE = 0.6892 ; Test RMSE = 0.9136
# Iteration: 250 ; Train RMSE = 0.6658 ; Test RMSE = 0.9142
# Iteration: 260 ; Train RMSE = 0.6425 ; Test RMSE = 0.9153
# Iteration: 270 ; Train RMSE = 0.6196 ; Test RMSE = 0.9168
# Iteration: 280 ; Train RMSE = 0.5973 ; Test RMSE = 0.9187
# Iteration: 290 ; Train RMSE = 0.5756 ; Test RMSE = 0.9209
# Iteration: 300 ; Train RMSE = 0.5548 ; Test RMSE = 0.9232
# K = 90
# Iteration: 10 ; Train RMSE = 0.9670 ; Test RMSE = 0.9807
# Iteration: 20 ; Train RMSE = 0.9420 ; Test RMSE = 0.9622
# Iteration: 30 ; Train RMSE = 0.9310 ; Test RMSE = 0.9551
# Iteration: 40 ; Train RMSE = 0.9246 ; Test RMSE = 0.9515
# Iteration: 50 ; Train RMSE = 0.9204 ; Test RMSE = 0.9493
# Iteration: 60 ; Train RMSE = 0.9174 ; Test RMSE = 0.9480
# Iteration: 70 ; Train RMSE = 0.9148 ; Test RMSE = 0.9470
# Iteration: 80 ; Train RMSE = 0.9125 ; Test RMSE = 0.9462
# Iteration: 90 ; Train RMSE = 0.9099 ; Test RMSE = 0.9454
# Iteration: 100 ; Train RMSE = 0.9068 ; Test RMSE = 0.9445
# Iteration: 110 ; Train RMSE = 0.9027 ; Test RMSE = 0.9432
# Iteration: 120 ; Train RMSE = 0.8970 ; Test RMSE = 0.9413
# Iteration: 130 ; Train RMSE = 0.8892 ; Test RMSE = 0.9387
# Iteration: 140 ; Train RMSE = 0.8790 ; Test RMSE = 0.9353
# Iteration: 150 ; Train RMSE = 0.8666 ; Test RMSE = 0.9315
# Iteration: 160 ; Train RMSE = 0.8525 ; Test RMSE = 0.9277
# Iteration: 170 ; Train RMSE = 0.8368 ; Test RMSE = 0.9242
# Iteration: 180 ; Train RMSE = 0.8197 ; Test RMSE = 0.9210
# Iteration: 190 ; Train RMSE = 0.8012 ; Test RMSE = 0.9183
# Iteration: 200 ; Train RMSE = 0.7812 ; Test RMSE = 0.9160
# Iteration: 210 ; Train RMSE = 0.7601 ; Test RMSE = 0.9142
# Iteration: 220 ; Train RMSE = 0.7380 ; Test RMSE = 0.9130
# Iteration: 230 ; Train RMSE = 0.7151 ; Test RMSE = 0.9124
# Iteration: 240 ; Train RMSE = 0.6918 ; Test RMSE = 0.9124
# Iteration: 250 ; Train RMSE = 0.6683 ; Test RMSE = 0.9130
# Iteration: 260 ; Train RMSE = 0.6448 ; Test RMSE = 0.9140
# Iteration: 270 ; Train RMSE = 0.6216 ; Test RMSE = 0.9154
# Iteration: 280 ; Train RMSE = 0.5989 ; Test RMSE = 0.9172
# Iteration: 290 ; Train RMSE = 0.5769 ; Test RMSE = 0.9192
# Iteration: 300 ; Train RMSE = 0.5556 ; Test RMSE = 0.9215
# K = 100
# Iteration: 10 ; Train RMSE = 0.9670 ; Test RMSE = 0.9807
# Iteration: 20 ; Train RMSE = 0.9421 ; Test RMSE = 0.9622
# Iteration: 30 ; Train RMSE = 0.9311 ; Test RMSE = 0.9552
# Iteration: 40 ; Train RMSE = 0.9247 ; Test RMSE = 0.9515
# Iteration: 50 ; Train RMSE = 0.9206 ; Test RMSE = 0.9494
# Iteration: 60 ; Train RMSE = 0.9175 ; Test RMSE = 0.9480
# Iteration: 70 ; Train RMSE = 0.9151 ; Test RMSE = 0.9471
# Iteration: 80 ; Train RMSE = 0.9128 ; Test RMSE = 0.9463
# Iteration: 90 ; Train RMSE = 0.9105 ; Test RMSE = 0.9456
# Iteration: 100 ; Train RMSE = 0.9076 ; Test RMSE = 0.9449
# Iteration: 110 ; Train RMSE = 0.9039 ; Test RMSE = 0.9438
# Iteration: 120 ; Train RMSE = 0.8988 ; Test RMSE = 0.9423
# Iteration: 130 ; Train RMSE = 0.8917 ; Test RMSE = 0.9400
# Iteration: 140 ; Train RMSE = 0.8822 ; Test RMSE = 0.9370
# Iteration: 150 ; Train RMSE = 0.8703 ; Test RMSE = 0.9334
# Iteration: 160 ; Train RMSE = 0.8567 ; Test RMSE = 0.9298
# Iteration: 170 ; Train RMSE = 0.8415 ; Test RMSE = 0.9264
# Iteration: 180 ; Train RMSE = 0.8250 ; Test RMSE = 0.9233
# Iteration: 190 ; Train RMSE = 0.8070 ; Test RMSE = 0.9207
# Iteration: 200 ; Train RMSE = 0.7874 ; Test RMSE = 0.9185
# Iteration: 210 ; Train RMSE = 0.7665 ; Test RMSE = 0.9167
# Iteration: 220 ; Train RMSE = 0.7442 ; Test RMSE = 0.9155
# Iteration: 230 ; Train RMSE = 0.7210 ; Test RMSE = 0.9148
# Iteration: 240 ; Train RMSE = 0.6972 ; Test RMSE = 0.9147
# Iteration: 250 ; Train RMSE = 0.6731 ; Test RMSE = 0.9152
# Iteration: 260 ; Train RMSE = 0.6489 ; Test RMSE = 0.9161
# Iteration: 270 ; Train RMSE = 0.6251 ; Test RMSE = 0.9175
# Iteration: 280 ; Train RMSE = 0.6017 ; Test RMSE = 0.9192
# Iteration: 290 ; Train RMSE = 0.5790 ; Test RMSE = 0.9212
# Iteration: 300 ; Train RMSE = 0.5570 ; Test RMSE = 0.9234
# K = 110
# Iteration: 10 ; Train RMSE = 0.9671 ; Test RMSE = 0.9807
# Iteration: 20 ; Train RMSE = 0.9421 ; Test RMSE = 0.9623
# Iteration: 30 ; Train RMSE = 0.9311 ; Test RMSE = 0.9552
# Iteration: 40 ; Train RMSE = 0.9248 ; Test RMSE = 0.9515
# Iteration: 50 ; Train RMSE = 0.9207 ; Test RMSE = 0.9494
# Iteration: 60 ; Train RMSE = 0.9177 ; Test RMSE = 0.9480
# Iteration: 70 ; Train RMSE = 0.9152 ; Test RMSE = 0.9470
# Iteration: 80 ; Train RMSE = 0.9130 ; Test RMSE = 0.9463
# Iteration: 90 ; Train RMSE = 0.9107 ; Test RMSE = 0.9455
# Iteration: 100 ; Train RMSE = 0.9080 ; Test RMSE = 0.9447
# Iteration: 110 ; Train RMSE = 0.9043 ; Test RMSE = 0.9435
# Iteration: 120 ; Train RMSE = 0.8993 ; Test RMSE = 0.9419
# Iteration: 130 ; Train RMSE = 0.8923 ; Test RMSE = 0.9395
# Iteration: 140 ; Train RMSE = 0.8830 ; Test RMSE = 0.9362
# Iteration: 150 ; Train RMSE = 0.8715 ; Test RMSE = 0.9325
# Iteration: 160 ; Train RMSE = 0.8582 ; Test RMSE = 0.9287
# Iteration: 170 ; Train RMSE = 0.8435 ; Test RMSE = 0.9252
# Iteration: 180 ; Train RMSE = 0.8275 ; Test RMSE = 0.9220
# Iteration: 190 ; Train RMSE = 0.8101 ; Test RMSE = 0.9192
# Iteration: 200 ; Train RMSE = 0.7911 ; Test RMSE = 0.9168
# Iteration: 210 ; Train RMSE = 0.7708 ; Test RMSE = 0.9148
# Iteration: 220 ; Train RMSE = 0.7492 ; Test RMSE = 0.9132
# Iteration: 230 ; Train RMSE = 0.7265 ; Test RMSE = 0.9122
# Iteration: 240 ; Train RMSE = 0.7031 ; Test RMSE = 0.9117
# Iteration: 250 ; Train RMSE = 0.6793 ; Test RMSE = 0.9118
# Iteration: 260 ; Train RMSE = 0.6552 ; Test RMSE = 0.9122
# Iteration: 270 ; Train RMSE = 0.6312 ; Test RMSE = 0.9132
# Iteration: 280 ; Train RMSE = 0.6076 ; Test RMSE = 0.9146
# Iteration: 290 ; Train RMSE = 0.5845 ; Test RMSE = 0.9162
# Iteration: 300 ; Train RMSE = 0.5621 ; Test RMSE = 0.9181
# K = 120
# Iteration: 10 ; Train RMSE = 0.9671 ; Test RMSE = 0.9807
# Iteration: 20 ; Train RMSE = 0.9421 ; Test RMSE = 0.9622
# Iteration: 30 ; Train RMSE = 0.9312 ; Test RMSE = 0.9551
# Iteration: 40 ; Train RMSE = 0.9249 ; Test RMSE = 0.9515
# Iteration: 50 ; Train RMSE = 0.9208 ; Test RMSE = 0.9494
# Iteration: 60 ; Train RMSE = 0.9178 ; Test RMSE = 0.9480
# Iteration: 70 ; Train RMSE = 0.9154 ; Test RMSE = 0.9470
# Iteration: 80 ; Train RMSE = 0.9133 ; Test RMSE = 0.9463
# Iteration: 90 ; Train RMSE = 0.9111 ; Test RMSE = 0.9456
# Iteration: 100 ; Train RMSE = 0.9086 ; Test RMSE = 0.9448
# Iteration: 110 ; Train RMSE = 0.9052 ; Test RMSE = 0.9437
# Iteration: 120 ; Train RMSE = 0.9006 ; Test RMSE = 0.9421
# Iteration: 130 ; Train RMSE = 0.8941 ; Test RMSE = 0.9398
# Iteration: 140 ; Train RMSE = 0.8854 ; Test RMSE = 0.9367
# Iteration: 150 ; Train RMSE = 0.8745 ; Test RMSE = 0.9330
# Iteration: 160 ; Train RMSE = 0.8619 ; Test RMSE = 0.9293
# Iteration: 170 ; Train RMSE = 0.8480 ; Test RMSE = 0.9259
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 19
#      16 mf = NEW_MF(R_temp, hyper_params)
#      18 test_set = mf.set_test(ratings_test)
# ---> 19 result = mf.test()
#      20 index.append(K)
#      21 results.append(result)
#
# Cell In[7], line 105, in NEW_MF.test(self)
#     103 for i in range(self.iterations):
#     104     np.random.shuffle(self.samples)
# --> 105     self.sgd()
#     106     rmse1 = self.rmse()
#     107     rmse2 = self.test_rmse()
#
# Cell In[7], line 62, in NEW_MF.sgd(self)
#      60 self.P[i, :] += self.alpha * ((e * self.Q[j, :]) - (self.beta * self.P[i, :]))
#      61 # Q 행렬 계산 및 업데이트
# ---> 62 self.Q[j, :] += self.alpha * ((e * self.P[i, :]) - (self.beta * self.Q[j, :]))
#
# KeyboardInterrupt:

# %%
summary = []
for i in range(len(results)):
    RMSE = []
    for result in results[i]:
        RMSE.append(result[2])
    min = np.min(RMSE)
    j = RMSE.index(min)
    summary.append([index[i], j+1, RMSE[j]])
